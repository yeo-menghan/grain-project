# %%
import json

with open('./data/drivers.json', 'r') as f:
    data = json.load(f)

wedding_count = 0

for driver in data:
    if 'capabilities' in driver and 'wedding' in driver['capabilities']:
        wedding_count += 1

print(f"Number of drivers tagged 'wedding': {wedding_count}")
# Out:
# Number of drivers tagged 'wedding': 14

# %%
import json

with open('./data/orders.json', 'r') as f:
    data = json.load(f)

wedding_count = 0

for order in data:
    if 'tags' in order and 'wedding' in order['tags']:
        wedding_count += 1

print(f"Number of orders tagged 'wedding': {wedding_count}")
# Out:
# Number of orders tagged 'wedding': 36

# %%
import json
from collections import defaultdict
from datetime import datetime

# Load orders
with open('./data/orders.json', 'r') as f:
    orders = json.load(f)

# Count wedding orders per date
wedding_per_date = defaultdict(int)

for order in orders:
    if 'tags' in order and 'wedding' in order['tags']:
        date = order['pickup_time'][:10]  # Extract 'YYYY-MM-DD'
        wedding_per_date[date] += 1

# Print distribution and check if within capacity
driver_capacity = 14  # Number of available drivers for wedding orders

print(f"{'Date':<12} {'Wedding Orders':<15} {'Fits Capacity?'}")
print('-' * 40)
for date in sorted(wedding_per_date):
    count = wedding_per_date[date]
    fits = "YES" if count <= driver_capacity else "NO"
    print(f"{date:<12} {count:<15} {fits}")
# Out:
# Date         Wedding Orders  Fits Capacity?
# ----------------------------------------
# 2024-11-02   34              NO
# 2024-11-03   2               YES

# %%
import pandas as pd
import json
from datetime import datetime

# Load data
with open('./data/orders.json') as f:
    orders = json.load(f)
with open('./data/drivers.json') as f:
    drivers = json.load(f)

# Feature engineering for orders
for o in orders:
    o['is_wedding'] = 'wedding' in o.get('tags', [])
    o['is_vip'] = 'vip' in o.get('tags', [])
    o['pickup_dt'] = datetime.fromisoformat(o['pickup_time'])
    o['start_dt'] = datetime.fromisoformat(o['setup_time'])
    o['end_dt'] = datetime.fromisoformat(o['teardown_time'])
    o['duration_hours'] = (o['end_dt'] - o['start_dt']).total_seconds() / 3600

# df_orders = pd.DataFrame([o for o in orders if o['is_wedding']])

df_orders = pd.DataFrame(orders)

# Priority score: VIP first, then pax, then shorter duration
df_orders['priority_score'] = (
    df_orders['is_vip'].astype(int) * 1000 +
    df_orders['pax_count'] +
    (10 - df_orders['duration_hours'])  # shorter duration preferred
)
df_orders = df_orders.sort_values(['priority_score'], ascending=False)

# %%
drivers_capable = []
for d in drivers:
    drivers_capable.append({
        **d,
        'assigned_orders': [],        # To keep assigned orders
        'assigned_on_date': {}        # date: list of (start_dt, end_dt)
    })

# %% [markdown]
# ### Greedy

# %%
# --- Greedy Assignment ---
assignment = []

def is_time_conflict(new_start, new_end, assigned_slots):
    """Return True if new order overlaps any assigned slot."""
    for s, e in assigned_slots:
        if not (new_end <= s or new_start >= e):
            return True
    return False

for idx, order in df_orders.iterrows():
    order_assigned = False
    order_date = order['start_dt'].date()
    # Rank drivers: region match first, then fewest assigned on date, then highest capacity
    ranked_drivers = sorted(
        drivers_capable,
        key=lambda d: (
            d['preferred_region'] != order['region'],  # region match = 0, else 1
            len(d['assigned_on_date'].get(order_date, [])),  # fewest assigned today
            -d['max_orders_per_day']  # higher capacity preferred
        )
    )
    for driver in ranked_drivers:
        # --- Capability check for wedding orders ---
        if order['is_wedding'] and ('capabilities' not in driver or 'wedding' not in driver['capabilities']):
            continue
        assigned_today = driver['assigned_on_date'].get(order_date, [])
        if len(assigned_today) >= driver['max_orders_per_day']:
            continue  # reached max capacity
        if is_time_conflict(order['start_dt'], order['end_dt'], assigned_today):
            continue  # overlapping
        # Assign
        driver['assigned_orders'].append(order['order_id'])
        driver['assigned_on_date'].setdefault(order_date, []).append((order['start_dt'], order['end_dt']))
        assignment.append({
            'order_id': order['order_id'],
            'driver_id': driver['driver_id'],
            'order_priority': order['priority_score'],
            'pickup_dt': order['pickup_dt'],
            'end_dt': order['end_dt'],
            'is_wedding': order['is_wedding'],
            'is_vip': order['is_vip'],
            'pax_count': order['pax_count'],
            'region': order['region']
        })
        order_assigned = True
        break  # move to next order

    if not order_assigned:
        assignment.append({
            'order_id': order['order_id'],
            'driver_id': None,  # Not assigned
            'order_priority': order['priority_score'],
            'pickup_dt': order['pickup_dt'],
            'end_dt': order['end_dt'],
            'is_wedding': order['is_wedding'],
            'is_vip': order['is_vip'],
            'pax_count': order['pax_count'],
            'region': order['region']
        })

# --- Results as DataFrame ---
df_assign = pd.DataFrame(assignment)

assigned_df = df_assign[df_assign['driver_id'].notnull()]
unassigned_df = df_assign[df_assign['driver_id'].isnull()]

print("Assigned orders summary:")
display(assigned_df[['order_id', 'driver_id', 'order_priority', 'pickup_dt', 'end_dt', 'is_wedding', 'is_vip', 'pax_count', 'region']])

print(f"\nTotal assigned: {len(assigned_df)} / {len(df_assign)}")
print("Unassigned orders:")
display(unassigned_df[['order_id', 'order_priority', 'pickup_dt', 'end_dt', 'is_wedding', 'is_vip', 'pax_count', 'region']])
# Out:
# Assigned orders summary:
#    order_id driver_id  order_priority           pickup_dt              end_dt  \
# 0     Q3247   DRV-022          1207.0 2024-11-02 20:30:00 2024-11-03 00:30:00
# 1     Q3958   DRV-013          1207.0 2024-11-02 18:45:00 2024-11-02 22:45:00
# 2     Q2717   DRV-008          1207.0 2024-11-02 19:45:00 2024-11-02 23:45:00
# 3     Q3819   DRV-052          1207.0 2024-11-02 20:45:00 2024-11-03 00:45:00
# 4     P8887   DRV-041          1207.0 2024-11-02 20:15:00 2024-11-03 00:15:00
# 5     P6984   DRV-064          1207.0 2024-11-02 18:45:00 2024-11-02 22:45:00
# 6     Q4627   DRV-055          1207.0 2024-11-02 19:00:00 2024-11-02 23:00:00
# 7     N8029   DRV-026          1207.0 2024-11-02 18:30:00 2024-11-02 22:30:00
# 8     P7916   DRV-016          1187.0 2024-11-02 20:15:00 2024-11-03 00:15:00
# 9     P4347   DRV-038          1187.0 2024-11-02 19:30:00 2024-11-02 23:30:00
# 10    P7015   DRV-043          1187.0 2024-11-02 20:45:00 2024-11-03 00:45:00
# 11    N8347   DRV-056          1157.0 2024-11-02 19:00:00 2024-11-02 23:00:00
# 12    P2927   DRV-013          1157.0 2024-11-03 01:15:00 2024-11-03 05:15:00
# 13    K9492   DRV-035          1157.0 2024-11-02 18:00:00 2024-11-02 22:00:00
# 14    O9254   DRV-023          1157.0 2024-11-02 20:00:00 2024-11-03 00:00:00
# 19    P2994   DRV-008           127.0 2024-11-03 02:00:00 2024-11-03 06:00:00
# 29    Q5402   DRV-025           107.0 2024-11-02 22:00:00 2024-11-03 02:00:00
# 33    O9178   DRV-039           105.0 2024-11-02 16:00:00 2024-11-02 22:00:00
# 37    P5729   DRV-025            87.0 2024-11-03 02:45:00 2024-11-03 06:45:00
# 38    P9767   DRV-039            87.0 2024-11-03 02:45:00 2024-11-03 06:45:00
# 40    N5760   DRV-050            87.0 2024-11-03 00:30:00 2024-11-03 04:30:00
# 41    Q1662   DRV-050            67.0 2024-11-02 20:15:00 2024-11-03 00:15:00
# 42    P9765   DRV-037            67.0 2024-11-03 00:00:00 2024-11-03 04:00:00
# 43    P9764   DRV-014            67.0 2024-11-03 00:15:00 2024-11-03 04:15:00
# 44    P6569   DRV-036            65.0 2024-11-02 15:45:00 2024-11-02 21:45:00
# 45    O9177   DRV-037            65.0 2024-11-02 15:45:00 2024-11-02 21:45:00
# 46    O4397   DRV-042            61.0 2024-11-02 14:30:00 2024-11-03 00:30:00
# 47    O4346   DRV-012            61.0 2024-11-02 15:30:00 2024-11-03 01:30:00
# 48    P9766   DRV-015            47.0 2024-11-03 01:45:00 2024-11-03 05:45:00
# 49    Q3374   DRV-034            37.0 2024-11-03 02:15:00 2024-11-03 06:15:00
# 50    P6567   DRV-020            35.0 2024-11-02 21:30:00 2024-11-03 03:30:00
# 51    Q3372   DRV-018            32.0 2024-11-02 19:00:00 2024-11-02 23:00:00
# 52    O4398   DRV-027            31.0 2024-11-02 14:45:00 2024-11-03 00:45:00
# 53    Q3371   DRV-051            27.0 2024-11-02 19:30:00 2024-11-02 23:30:00
# 54    Q4282   DRV-032            22.0 2024-11-02 19:45:00 2024-11-02 23:45:00
# 55    Q4280   DRV-018            22.0 2024-11-03 02:45:00 2024-11-03 06:45:00
# 56    Q3373   DRV-068            22.0 2024-11-02 19:15:00 2024-11-02 23:15:00
# 57    P4047   DRV-068            17.0 2024-11-03 01:30:00 2024-11-03 05:30:00
# 58    Q4284   DRV-001            17.0 2024-11-02 19:45:00 2024-11-02 23:45:00
# 59    Q3370   DRV-027            17.0 2024-11-03 02:00:00 2024-11-03 06:00:00
#
#     is_wedding  is_vip  pax_count   region
# 0         True    True        200    north
# 1         True    True        200    north
# 2         True    True        200     east
# 3         True    True        200     east
# 4         True    True        200    north
# 5         True    True        200     east
# 6         True    True        200  central
# 7         True    True        200     east
# 8         True    True        180     east
# 9         True    True        180    north
# 10        True    True        180     west
# 11        True    True        150  central
# 12        True    True        150     west
# 13        True    True        150  central
# 14        True    True        150     west
# 19        True   False        120     east
# 29       False   False        100  central
# 33       False   False        100     east
# 37       False   False         80  central
# 38       False   False         80     east
# 40       False   False         80     west
# 41       False   False         60     west
# 42       False   False         60     east
# 43       False   False         60     east
# 44       False   False         60  central
# 45       False   False         60     east
# 46       False   False         60  central
# 47       False   False         60  central
# 48       False   False         40     east
# 49       False   False         30     east
# 50       False   False         30  central
# 51       False   False         25    north
# 52       False   False         30  central
# 53       False   False         20    north
# 54       False   False         15    north
# 55       False   False         15    north
# 56       False   False         15     west
# 57       False   False         10     west
# 58       False   False         10    north
# 59       False   False         10    north
# Total assigned: 40 / 60
# Unassigned orders:
#    order_id  order_priority           pickup_dt              end_dt  \
# 15    Q1619          1157.0 2024-11-02 19:45:00 2024-11-02 23:45:00
# 16    P4436          1157.0 2024-11-02 19:15:00 2024-11-02 23:15:00
# 17    O9950          1157.0 2024-11-02 18:30:00 2024-11-02 22:30:00
# 18    Q5082          1157.0 2024-11-02 19:00:00 2024-11-02 23:00:00
# 20    Q0753           127.0 2024-11-02 19:45:00 2024-11-02 23:45:00
# 21    P5232           127.0 2024-11-02 19:15:00 2024-11-02 23:15:00
# 22    Q3548           127.0 2024-11-02 18:45:00 2024-11-02 22:45:00
# 23    O3425           127.0 2024-11-02 19:15:00 2024-11-02 23:15:00
# 24    P6985           107.0 2024-11-02 20:45:00 2024-11-03 00:45:00
# 25    Q1717           107.0 2024-11-02 19:00:00 2024-11-02 23:00:00
# 26    P9688           107.0 2024-11-02 19:00:00 2024-11-02 23:00:00
# 27    N8980           107.0 2024-11-02 18:00:00 2024-11-02 22:00:00
# 28    P9890           107.0 2024-11-02 19:15:00 2024-11-02 23:15:00
# 30    Q4974           107.0 2024-11-02 18:15:00 2024-11-02 22:15:00
# 31    Q1194           107.0 2024-11-02 19:30:00 2024-11-02 23:30:00
# 32    O1841           107.0 2024-11-02 19:15:00 2024-11-02 23:15:00
# 34    Q3490            87.0 2024-11-02 18:45:00 2024-11-02 22:45:00
# 35    P4506            87.0 2024-11-02 20:45:00 2024-11-03 00:45:00
# 36    P8848            87.0 2024-11-02 19:45:00 2024-11-02 23:45:00
# 39    N4492            87.0 2024-11-02 20:30:00 2024-11-03 00:30:00
#
#     is_wedding  is_vip  pax_count   region
# 15        True    True        150    north
# 16        True    True        150     east
# 17        True    True        150  central
# 18        True    True        150    north
# 20        True   False        120     east
# 21        True   False        120    north
# 22        True   False        120     east
# 23        True   False        120    north
# 24        True   False        100     east
# 25        True   False        100    north
# 26        True   False        100     west
# 27        True   False        100     west
# 28        True   False        100    north
# 30        True   False        100     east
# 31        True   False        100  central
# 32        True   False        100    north
# 34        True   False         80    north
# 35        True   False         80     east
# 36        True   False         80     west
# 39        True   False         80    north

# %% [markdown]
# ### PuLP

# %%
import pulp
import pandas as pd
from itertools import product

# Assume df_orders and drivers_capable are already defined as before

# Step 1: Build a list of possible driver-order assignments
assignments = []
order_idx = df_orders.index
for i in order_idx:
    o = df_orders.loc[i]
    for d, driver in enumerate(drivers_capable):
        # If this is a wedding order, the driver must have wedding capability
        if o['is_wedding'] and ('capabilities' not in driver or 'wedding' not in driver['capabilities']):
            continue
        # Otherwise, any driver can be assigned
        assignments.append((i, d))

# Region match bonus
region_bonus = 10

# Step 2: Define the problem
prob = pulp.LpProblem("OrderAssignment", pulp.LpMaximize)

# Decision variables: x[i, d] = 1 if order i is assigned to driver d
x = pulp.LpVariable.dicts("assign", assignments, 0, 1, pulp.LpBinary)

# Objective: Maximize total priority score + region match bonus
prob += pulp.lpSum([
    x[(i, d)] * (
        df_orders.loc[i]['priority_score']
        + (region_bonus if drivers_capable[d]['preferred_region'] == df_orders.loc[i]['region'] else 0)
    )
    for (i, d) in assignments
])

# Constraint: Each order assigned at most once
for i in order_idx:
    prob += pulp.lpSum([x[(i, d)] for d in range(len(drivers_capable)) if (i, d) in x]) <= 1

# Constraint: Each driver can do at most max_orders_per_day per day
for d, driver in enumerate(drivers_capable):
    dates = set(df_orders['pickup_dt'])
    for date in dates:
        orders_on_date = df_orders[df_orders['pickup_dt'] == date].index
        prob += pulp.lpSum([x[(i, d)] for i in orders_on_date if (i, d) in x]) <= driver['max_orders_per_day']

# Constraint: No driver can take overlapping orders (precompute conflict pairs)
def overlap(o1, o2):
    return not (o1['end_dt'] <= o2['start_dt'] or o1['start_dt'] >= o2['end_dt'])

for d, driver in enumerate(drivers_capable):
    for i1, i2 in product(df_orders.index, repeat=2):
        if i1 < i2:
            o1, o2 = df_orders.loc[i1], df_orders.loc[i2]
            # If this is a wedding order, the driver must have wedding capability
            if (o1['is_wedding'] and ('capabilities' not in driver or 'wedding' not in driver['capabilities'])):
                continue
            if (o2['is_wedding'] and ('capabilities' not in driver or 'wedding' not in driver['capabilities'])):
                continue
            # Now check overlap
            if overlap(o1, o2):
                if (i1, d) in x and (i2, d) in x:
                    prob += x[(i1, d)] + x[(i2, d)] <= 1

# Solve!
prob.solve()

# Extract assignment results
assigned = []
for (i, d), var in x.items():
    if var.varValue > 0.5:
        assigned.append((df_orders.loc[i]['order_id'], drivers_capable[d]['driver_id']))

print(f"Assigned {len(assigned)} orders out of {len(df_orders)} (ILP)")

# Show unassigned orders
assigned_ids = set(a[0] for a in assigned)
unassigned_orders = df_orders[~df_orders['order_id'].isin(assigned_ids)]
print(unassigned_orders[['order_id', 'priority_score', 'is_vip', 'pax_count', 'region']])
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/yeo_menghan/Documents/personal-projects/grain-project/.venv/lib/python3.12/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/_l/9yt9fjns3yl8khq3hlylkj7w0000gn/T/a51c59890bfe42e8b81f7aba7835bfc6-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/_l/9yt9fjns3yl8khq3hlylkj7w0000gn/T/a51c59890bfe42e8b81f7aba7835bfc6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 26357 COLUMNS
# At line 85942 RHS
# At line 112295 BOUNDS
# At line 114480 ENDATA
# Problem MODEL has 26352 rows, 2184 columns and 53032 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 26099 - 0.21 seconds
# Cgl0008I 60 inequality constraints converted to equality constraints
# Cgl0003I 0 fixed, 0 tightened bounds, 22733 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 21888 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 21118 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 19020 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 17214 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 17355 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 16682 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 14691 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 0 tightened bounds, 15597 strengthened rows, 0 substitutions
# Cgl0005I 60 SOS with 2244 members
# Cgl0004I processed model has 18859 rows, 2244 columns (2244 integer (2244 of which binary)) and 188625 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 88 integers unsatisfied sum - 44
# Cbc0038I Pass   1: (8.59 seconds) suminf.    0.00000 (0) obj. -2238 iterations 366
# Cbc0038I Solution found of -2238
# Cbc0038I Before mini branch and bound, 2096 integers at bound fixed and 16 continuous
# Cbc0038I Full problem 18859 rows 2244 columns, reduced to 358 rows 78 columns
# Cbc0038I Mini branch and bound improved solution from -2238 to -10343 (8.70 seconds)
# Cbc0038I Round again with cutoff of -11919.5
# Cbc0038I Pass   2: (8.73 seconds) suminf.    0.06338 (3) obj. -11919.5 iterations 39
# Cbc0038I Pass   3: (8.75 seconds) suminf.    0.02113 (1) obj. -11919.5 iterations 10
# Cbc0038I Solution found of -13101
# Cbc0038I Before mini branch and bound, 2087 integers at bound fixed and 24 continuous
# Cbc0038I Full problem 18859 rows 2244 columns, reduced to 396 rows 85 columns
# Cbc0038I Mini branch and bound improved solution from -13101 to -16159 (8.88 seconds)
# Cbc0038I Round again with cutoff of -18147.8
# Cbc0038I Pass   4: (8.92 seconds) suminf.    7.29715 (15) obj. -18147.8 iterations 32
# Cbc0038I Pass   5: (8.93 seconds) suminf.    7.29715 (15) obj. -18147.8 iterations 5
# Cbc0038I Pass   6: (8.95 seconds) suminf.    7.50000 (15) obj. -18382.5 iterations 41
# Cbc0038I Pass   7: (8.96 seconds) suminf.    7.29715 (15) obj. -18147.8 iterations 45
# Cbc0038I Pass   8: (8.97 seconds) suminf.    6.10078 (16) obj. -18147.8 iterations 13
# Cbc0038I Pass   9: (9.00 seconds) suminf.    4.51585 (12) obj. -18147.8 iterations 14
# Cbc0038I Pass  10: (9.01 seconds) suminf.    3.30317 (7) obj. -18147.8 iterations 16
# Cbc0038I Pass  11: (9.02 seconds) suminf.    3.50000 (7) obj. -18377.5 iterations 56
# Cbc0038I Pass  12: (9.04 seconds) suminf.    3.30317 (7) obj. -18147.8 iterations 55
# Cbc0038I Pass  13: (9.09 seconds) suminf.   26.50000 (53) obj. -20534.5 iterations 320
# Cbc0038I Pass  14: (9.14 seconds) suminf.    4.15886 (9) obj. -18147.8 iterations 258
# Cbc0038I Pass  15: (9.16 seconds) suminf.    4.15886 (9) obj. -18147.8 iterations 11
# Cbc0038I Pass  16: (9.17 seconds) suminf.    3.50000 (7) obj. -18537.5 iterations 45
# Cbc0038I Pass  17: (9.18 seconds) suminf.    0.81590 (5) obj. -18147.8 iterations 51
# Cbc0038I Pass  18: (9.21 seconds) suminf.    0.22317 (4) obj. -18147.8 iterations 146
# Cbc0038I Pass  19: (9.22 seconds) suminf.    1.50000 (3) obj. -19607.5 iterations 124
# Cbc0038I Pass  20: (9.24 seconds) suminf.    0.23838 (1) obj. -18147.8 iterations 123
# Cbc0038I Solution found of -19029
# Cbc0038I Before mini branch and bound, 2006 integers at bound fixed and 21 continuous
# Cbc0038I Full problem 18859 rows 2244 columns, reduced to 728 rows 146 columns
# Cbc0038I Mini branch and bound improved solution from -19029 to -19474 (9.45 seconds)
# Cbc0038I Round again with cutoff of -21462.2
# Cbc0038I Pass  21: (9.48 seconds) suminf.    9.84685 (20) obj. -21462.2 iterations 17
# Cbc0038I Pass  22: (9.51 seconds) suminf.    7.15184 (15) obj. -21462.2 iterations 140
# Cbc0038I Pass  23: (9.52 seconds) suminf.    7.15184 (15) obj. -21462.2 iterations 0
# Cbc0038I Pass  24: (9.53 seconds) suminf.    6.54054 (15) obj. -21462.2 iterations 35
# Cbc0038I Pass  25: (9.55 seconds) suminf.    5.15613 (11) obj. -21462.2 iterations 43
# Cbc0038I Pass  26: (9.57 seconds) suminf.    5.50000 (11) obj. -21863.5 iterations 43
# Cbc0038I Pass  27: (9.61 seconds) suminf.   22.73977 (58) obj. -21462.2 iterations 307
# Cbc0038I Pass  28: (9.67 seconds) suminf.    9.82731 (20) obj. -21462.2 iterations 286
# Cbc0038I Pass  29: (9.68 seconds) suminf.    9.82731 (20) obj. -21462.2 iterations 7
# Cbc0038I Pass  30: (9.69 seconds) suminf.    8.00000 (16) obj. -21657 iterations 28
# Cbc0038I Pass  31: (9.71 seconds) suminf.    7.49490 (16) obj. -21462.2 iterations 57
# Cbc0038I Pass  32: (9.78 seconds) suminf.    6.83163 (14) obj. -21462.2 iterations 14
# Cbc0038I Pass  33: (9.86 seconds) suminf.    7.00000 (14) obj. -21657 iterations 56
# Cbc0038I Pass  34: (9.91 seconds) suminf.   26.02219 (59) obj. -21462.2 iterations 310
# Cbc0038I Pass  35: (9.97 seconds) suminf.   11.29871 (24) obj. -21462.2 iterations 336
# Cbc0038I Pass  36: (9.98 seconds) suminf.   10.76854 (22) obj. -21462.2 iterations 20
# Cbc0038I Pass  37: (9.99 seconds) suminf.   10.76854 (22) obj. -21462.2 iterations 19
# Cbc0038I Pass  38: (10.07 seconds) suminf.   21.67512 (54) obj. -21462.2 iterations 423
# Cbc0038I Pass  39: (10.12 seconds) suminf.    7.68470 (16) obj. -21462.2 iterations 251
# Cbc0038I Pass  40: (10.13 seconds) suminf.    7.68470 (16) obj. -21462.2 iterations 6
# Cbc0038I Pass  41: (10.14 seconds) suminf.    8.00000 (16) obj. -21827 iterations 44
# Cbc0038I Pass  42: (10.19 seconds) suminf.   24.51876 (50) obj. -21462.2 iterations 328
# Cbc0038I Pass  43: (10.23 seconds) suminf.    9.44676 (21) obj. -21462.2 iterations 253
# Cbc0038I Pass  44: (10.24 seconds) suminf.    8.97338 (18) obj. -21462.2 iterations 10
# Cbc0038I Pass  45: (10.30 seconds) suminf.    7.00000 (14) obj. -21488 iterations 62
# Cbc0038I Pass  46: (10.35 seconds) suminf.    6.97789 (14) obj. -21462.2 iterations 55
# Cbc0038I Pass  47: (10.40 seconds) suminf.    7.00000 (14) obj. -21488 iterations 54
# Cbc0038I Pass  48: (10.44 seconds) suminf.   22.10172 (67) obj. -21462.2 iterations 254
# Cbc0038I Pass  49: (10.49 seconds) suminf.    9.48850 (19) obj. -21462.2 iterations 256
# Cbc0038I Pass  50: (10.50 seconds) suminf.    9.48850 (19) obj. -21462.2 iterations 3
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 1819 integers at bound fixed and 18 continuous
# Cbc0038I Full problem 18859 rows 2244 columns, reduced to 3120 rows 323 columns
# Cbc0038I Mini branch and bound did not improve solution (11.67 seconds)
# Cbc0038I After 11.67 seconds - Feasibility pump exiting with objective of -19474 - took 3.02 seconds
# Cbc0012I Integer solution of -19474 found by feasibility pump after 0 iterations and 0 nodes (11.68 seconds)
# Cbc0038I Full problem 18859 rows 2244 columns, reduced to 362 rows 78 columns
# Cbc0031I 219 added rows had average density of 26.127854
# Cbc0013I At root node, 219 cuts changed objective from -26099 to -20967.113 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 24444 row cuts average 12.1 elements, 0 column cuts (0 active)  in 8.908 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 7717 row cuts average 330.8 elements, 0 column cuts (0 active)  in 4.338 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 4 row cuts average 13.8 elements, 0 column cuts (0 active)  in 0.464 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 2269 row cuts average 14.6 elements, 0 column cuts (0 active)  in 12.518 seconds - new frequency is 1
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 105 row cuts average 51.8 elements, 0 column cuts (0 active)  in 1.442 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.107 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 468 row cuts average 245.4 elements, 0 column cuts (0 active)  in 1.921 seconds - new frequency is 1
# Cbc0014I Cut generator 7 (ZeroHalf) - 134 row cuts average 12.3 elements, 0 column cuts (0 active)  in 37.729 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, -19474 best solution, best possible -20967.113 (192.21 seconds)
# Cbc0012I Integer solution of -19494 found by DiveCoefficient after 185376 iterations and 5 nodes (219.01 seconds)
# Cbc0012I Integer solution of -19524 found by DiveCoefficient after 189111 iterations and 6 nodes (224.79 seconds)
# Cbc0012I Integer solution of -19534 found by DiveCoefficient after 200123 iterations and 10 nodes (238.65 seconds)
# Cbc0038I Full problem 18859 rows 2244 columns, reduced to 864 rows 111 columns
# Cbc0038I Full problem 18859 rows 2244 columns, reduced to 235 rows 61 columns
# Cbc0010I After 100 nodes, 43 on tree, -19534 best solution, best possible -20967.113 (368.18 seconds)
# Cbc0004I Integer solution of -19554 found after 295301 iterations and 107 nodes (370.88 seconds)
# Cbc0038I Full problem 18859 rows 2244 columns, reduced to 888 rows 119 columns
# Cbc0010I After 200 nodes, 65 on tree, -19554 best solution, best possible -20967.113 (481.61 seconds)
# Cbc0004I Integer solution of -19564 found after 399236 iterations and 237 nodes (514.54 seconds)
# Cbc0038I Full problem 18859 rows 2244 columns, reduced to 873 rows 123 columns
# Cbc0010I After 300 nodes, 91 on tree, -19564 best solution, best possible -20967.113 (577.62 seconds)
# Cbc0010I After 400 nodes, 102 on tree, -19564 best solution, best possible -20967.113 (649.10 seconds)
# Cbc0010I After 500 nodes, 116 on tree, -19564 best solution, best possible -20967.113 (732.17 seconds)
# Cbc0038I Full problem 18859 rows 2244 columns, reduced to 51 rows 25 columns
# Cbc0038I Full problem 18859 rows 2244 columns, reduced to 286 rows 66 columns
# Cbc0010I After 600 nodes, 128 on tree, -19564 best solution, best possible -20967.113 (803.91 seconds)
# Cbc0038I Full problem 18859 rows 2244 columns, reduced to 789 rows 108 columns
# Cbc0010I After 700 nodes, 142 on tree, -19564 best solution, best possible -20967.113 (878.68 seconds)
# Cbc0038I Full problem 18859 rows 2244 columns, reduced to 738 rows 109 columns
# Cbc0010I After 800 nodes, 157 on tree, -19564 best solution, best possible -20967.113 (952.58 seconds)
# Cbc0038I Full problem 18859 rows 2244 columns, reduced to 405 rows 70 columns
# Cbc0010I After 900 nodes, 186 on tree, -19564 best solution, best possible -20967.113 (1043.99 seconds)
# Cbc0010I After 1000 nodes, 193 on tree, -19564 best solution, best possible -20967.113 (1109.29 seconds)
# Cbc0010I After 1100 nodes, 204 on tree, -19564 best solution, best possible -20967.113 (1178.35 seconds)
# Cbc0038I Full problem 18859 rows 2244 columns, reduced to 196 rows 56 columns
# Cbc0010I After 1200 nodes, 206 on tree, -19564 best solution, best possible -20967.113 (1245.52 seconds)
# Cbc0010I After 1300 nodes, 204 on tree, -19564 best solution, best possible -20967.113 (1300.48 seconds)
# Cbc0010I After 1400 nodes, 205 on tree, -19564 best solution, best possible -20967.113 (1360.39 seconds)
# Cbc0010I After 1500 nodes, 204 on tree, -19564 best solution, best possible -20967.113 (1412.19 seconds)
# Cbc0010I After 1600 nodes, 202 on tree, -19564 best solution, best possible -20967.113 (1466.01 seconds)
# Cbc0010I After 1700 nodes, 200 on tree, -19564 best solution, best possible -20967.113 (1516.25 seconds)
# Cbc0038I Full problem 18859 rows 2244 columns, reduced to 316 rows 53 columns
# Cbc0010I After 1800 nodes, 202 on tree, -19564 best solution, best possible -20967.113 (1564.42 seconds)
# Cbc0010I After 1900 nodes, 204 on tree, -19564 best solution, best possible -20967.113 (1610.78 seconds)
# Cbc0010I After 2000 nodes, 203 on tree, -19564 best solution, best possible -20967.113 (1663.21 seconds)
# Cbc0010I After 2100 nodes, 203 on tree, -19564 best solution, best possible -20967.113 (1713.02 seconds)
# Cbc0010I After 2200 nodes, 204 on tree, -19564 best solution, best possible -20967.113 (1765.99 seconds)
# Cbc0004I Integer solution of -19574 found after 1439439 iterations and 2273 nodes (1805.36 seconds)
# Cbc0010I After 2300 nodes, 205 on tree, -19574 best solution, best possible -20967.113 (1829.47 seconds)
# Cbc0038I Full problem 18859 rows 2244 columns, reduced to 782 rows 114 columns
# Cbc0010I After 2400 nodes, 217 on tree, -19574 best solution, best possible -20967.113 (1892.88 seconds)
# Cbc0010I After 2500 nodes, 236 on tree, -19574 best solution, best possible -20967.113 (1980.80 seconds)
# Cbc0010I After 2600 nodes, 237 on tree, -19574 best solution, best possible -20967.113 (2039.74 seconds)
# Cbc0010I After 2700 nodes, 246 on tree, -19574 best solution, best possible -20967.113 (2108.19 seconds)
# Cbc0010I After 2800 nodes, 246 on tree, -19574 best solution, best possible -20967.113 (2177.29 seconds)
# Cbc0010I After 2900 nodes, 250 on tree, -19574 best solution, best possible -20967.113 (2241.85 seconds)
# Cbc0010I After 3000 nodes, 251 on tree, -19574 best solution, best possible -20967.113 (2312.84 seconds)
# Cbc0010I After 3100 nodes, 258 on tree, -19574 best solution, best possible -20967.113 (2381.76 seconds)
# Cbc0010I After 3200 nodes, 260 on tree, -19574 best solution, best possible -20967.113 (2438.80 seconds)
# Cbc0010I After 3300 nodes, 265 on tree, -19574 best solution, best possible -20967.113 (2501.97 seconds)
# Cbc0010I After 3400 nodes, 264 on tree, -19574 best solution, best possible -20967.113 (2555.47 seconds)
# Cbc0010I After 3500 nodes, 269 on tree, -19574 best solution, best possible -20967.113 (2611.32 seconds)
# Cbc0038I Full problem 18859 rows 2244 columns, reduced to 131 rows 46 columns
# Cbc0010I After 3600 nodes, 265 on tree, -19574 best solution, best possible -20967.113 (2654.91 seconds)
# Cbc0010I After 3700 nodes, 266 on tree, -19574 best solution, best possible -20967.113 (2714.29 seconds)
# Cbc0010I After 3800 nodes, 267 on tree, -19574 best solution, best possible -20967.113 (2772.81 seconds)
# Cbc0010I After 3900 nodes, 268 on tree, -19574 best solution, best possible -20967.113 (2835.90 seconds)
# Cbc0010I After 4000 nodes, 276 on tree, -19574 best solution, best possible -20967.113 (2921.74 seconds)
# Cbc0010I After 4100 nodes, 285 on tree, -19574 best solution, best possible -20967.113 (2991.95 seconds)
# Cbc0010I After 4200 nodes, 290 on tree, -19574 best solution, best possible -20967.113 (3045.57 seconds)
# Cbc0010I After 4300 nodes, 288 on tree, -19574 best solution, best possible -20967.113 (3092.35 seconds)
# Cbc0010I After 4400 nodes, 286 on tree, -19574 best solution, best possible -20967.113 (3155.97 seconds)
# Cbc0010I After 4500 nodes, 292 on tree, -19574 best solution, best possible -20967.113 (3218.28 seconds)
# Cbc0010I After 4600 nodes, 294 on tree, -19574 best solution, best possible -20967.113 (3269.15 seconds)
# Cbc0010I After 4700 nodes, 297 on tree, -19574 best solution, best possible -20967.113 (3337.15 seconds)
# Cbc0010I After 4800 nodes, 307 on tree, -19574 best solution, best possible -20967.113 (3403.80 seconds)
# Cbc0038I Full problem 18859 rows 2244 columns, reduced to 183 rows 54 columns
# Cbc0010I After 4900 nodes, 312 on tree, -19574 best solution, best possible -20967.113 (3468.70 seconds)
# Cbc0010I After 5000 nodes, 323 on tree, -19574 best solution, best possible -20967.113 (3546.84 seconds)
# Cbc0010I After 5100 nodes, 332 on tree, -19574 best solution, best possible -20967.113 (3598.12 seconds)
# Cbc0010I After 5200 nodes, 333 on tree, -19574 best solution, best possible -20967.113 (3647.48 seconds)
# Cbc0010I After 5300 nodes, 329 on tree, -19574 best solution, best possible -20967.113 (3683.40 seconds)
# Cbc0010I After 5400 nodes, 332 on tree, -19574 best solution, best possible -20967.113 (3733.50 seconds)
# Cbc0010I After 5500 nodes, 329 on tree, -19574 best solution, best possible -20967.113 (3782.52 seconds)
# Cbc0010I After 5600 nodes, 327 on tree, -19574 best solution, best possible -20967.113 (3833.27 seconds)
# Cbc0010I After 5700 nodes, 332 on tree, -19574 best solution, best possible -20967.113 (3895.68 seconds)
# Cbc0010I After 5800 nodes, 331 on tree, -19574 best solution, best possible -20967.113 (3951.21 seconds)
# Cbc0010I After 5900 nodes, 327 on tree, -19574 best solution, best possible -20967.113 (4000.92 seconds)
# Cbc0038I Full problem 18859 rows 2244 columns, reduced to 277 rows 64 columns
# Cbc0010I After 6000 nodes, 329 on tree, -19574 best solution, best possible -20967.113 (4047.19 seconds)
# Cbc0010I After 6100 nodes, 326 on tree, -19574 best solution, best possible -20967.113 (4083.84 seconds)
# Cbc0010I After 6200 nodes, 330 on tree, -19574 best solution, best possible -20967.113 (4136.41 seconds)
# Cbc0010I After 6300 nodes, 329 on tree, -19574 best solution, best possible -20967.113 (4186.27 seconds)
# Cbc0010I After 6400 nodes, 325 on tree, -19574 best solution, best possible -20967.113 (4235.22 seconds)
# Cbc0010I After 6500 nodes, 325 on tree, -19574 best solution, best possible -20967.113 (4293.42 seconds)
# Cbc0010I After 6600 nodes, 330 on tree, -19574 best solution, best possible -20967.113 (4347.18 seconds)
# Cbc0010I After 6700 nodes, 329 on tree, -19574 best solution, best possible -20967.113 (4407.12 seconds)
# Cbc0010I After 6800 nodes, 327 on tree, -19574 best solution, best possible -20967.113 (4459.87 seconds)
# Cbc0010I After 6900 nodes, 325 on tree, -19574 best solution, best possible -20967.113 (4526.92 seconds)
# Cbc0010I After 7000 nodes, 327 on tree, -19574 best solution, best possible -20967.113 (4586.14 seconds)
# Cbc0010I After 7100 nodes, 317 on tree, -19574 best solution, best possible -20967.113 (4638.15 seconds)
# Cbc0038I Full problem 18859 rows 2244 columns, reduced to 379 rows 66 columns
# Cbc0010I After 7200 nodes, 309 on tree, -19574 best solution, best possible -20967.113 (4676.80 seconds)
# Cbc0010I After 7300 nodes, 296 on tree, -19574 best solution, best possible -20967.113 (4719.08 seconds)
# Cbc0010I After 7400 nodes, 286 on tree, -19574 best solution, best possible -20967.113 (4759.45 seconds)
# Cbc0010I After 7500 nodes, 273 on tree, -19574 best solution, best possible -20967.113 (4804.74 seconds)
# Cbc0010I After 7600 nodes, 268 on tree, -19574 best solution, best possible -20967.113 (4852.25 seconds)
# Cbc0010I After 7700 nodes, 260 on tree, -19574 best solution, best possible -20967.113 (4899.63 seconds)
# Cbc0027I Exiting on user event
# Cbc0005I Partial search - best objective -19574 (best possible -20967.113), took 4059601 iterations and 7764 nodes (4925.77 seconds)
# Cbc0032I Strong branching done 69390 times (3183951 iterations), fathomed 78 nodes and fixed 151 variables
# Cbc0035I Maximum depth 32, 1776679 variables fixed on reduced cost
# Cuts at root node changed objective from -26099 to -20967.1
# Probing was tried 21883 times and created 3033900 cuts of which 0 were active after adding rounds of cuts (236.632 seconds)
# Gomory was tried 21883 times and created 40774 cuts of which 0 were active after adding rounds of cuts (148.996 seconds)
# Knapsack was tried 100 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.464 seconds)
# Clique was tried 21883 times and created 91163 cuts of which 0 were active after adding rounds of cuts (603.959 seconds)
# MixedIntegerRounding2 was tried 100 times and created 105 cuts of which 0 were active after adding rounds of cuts (1.442 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.107 seconds)
# TwoMirCuts was tried 21883 times and created 734 cuts of which 0 were active after adding rounds of cuts (272.118 seconds)
# ZeroHalf was tried 100 times and created 134 cuts of which 0 were active after adding rounds of cuts (37.729 seconds)
#
# Result - User ctrl-cuser ctrl-c
#
# Objective value:                19574.00000000
# Upper bound:                    20967.113
# Gap:                            -0.07
# Enumerated nodes:               7764
# Total iterations:               4059601
# Time (CPU seconds):             4822.89
# Time (Wallclock seconds):       4926.10
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       4822.95   (Wallclock seconds):       4926.17
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 67
#      64                     prob += x[(i1, d)] + x[(i2, d)] <= 1
#      66 # Solve!
# ---> 67 prob.solve()
#      69 # Extract assignment results
#      70 assigned = []
#
# File ~/Documents/personal-projects/grain-project/.venv/lib/python3.12/site-packages/pulp/pulp.py:2092, in LpProblem.solve(self, solver, **kwargs)
#    2090 # time it
#    2091 self.startClock()
# -> 2092 status = solver.actualSolve(self, **kwargs)
#    2093 self.stopClock()
#    2094 self.restoreObjective(wasNone, dummyVar)
#
# File ~/Documents/personal-projects/grain-project/.venv/lib/python3.12/site-packages/pulp/apis/coin_api.py:144, in COIN_CMD.actualSolve(self, lp, **kwargs)
#     142 def actualSolve(self, lp: LpProblem, **kwargs):
#     143     """Solve a well formulated lp problem"""
# --> 144     return self.solve_CBC(lp, **kwargs)
#
# File ~/Documents/personal-projects/grain-project/.venv/lib/python3.12/site-packages/pulp/apis/coin_api.py:222, in COIN_CMD.solve_CBC(self, lp, use_mps)
#     220 else:
#     221     cbc = subprocess.Popen(args, stdout=pipe, stderr=pipe, stdin=devnull)
# --> 222 if cbc.wait() != 0:
#     223     if pipe:
#     224         pipe.close()
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/subprocess.py:1264, in Popen.wait(self, timeout)
#    1262     endtime = _time() + timeout
#    1263 try:
# -> 1264     return self._wait(timeout=timeout)
#    1265 except KeyboardInterrupt:
#    1266     # https://bugs.python.org/issue25942
#    1267     # The first keyboard interrupt waits briefly for the child to
#    1268     # exit under the common assumption that it also received the ^C
#    1269     # generated SIGINT and will exit rapidly.
#    1270     if timeout is not None:
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/subprocess.py:2053, in Popen._wait(self, timeout)
#    2051 if self.returncode is not None:
#    2052     break  # Another thread waited.
# -> 2053 (pid, sts) = self._try_wait(0)
#    2054 # Check the pid and loop as waitpid has been known to
#    2055 # return 0 even without WNOHANG in odd situations.
#    2056 # http://bugs.python.org/issue14396.
#    2057 if pid == self.pid:
#
# File /opt/homebrew/Caskroom/miniforge/base/lib/python3.12/subprocess.py:2011, in Popen._try_wait(self, wait_flags)
#    2009 """All callers to this function MUST hold self._waitpid_lock."""
#    2010 try:
# -> 2011     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    2012 except ChildProcessError:
#    2013     # This happens if SIGCLD is set to be ignored or waiting
#    2014     # for child processes has otherwise been disabled for our
#    2015     # process.  This child is dead, we can't get the status.
#    2016     pid = self.pid
#
# KeyboardInterrupt:

# %%
import pandas as pd
from collections import defaultdict

# 'assigned' is a list of (order_id, driver_id)
df_assigned = pd.DataFrame(assigned, columns=['order_id', 'driver_id'])

# Merge with order details (make sure to use the correct field names)
df_assigned_details = df_assigned.merge(
    df_orders,
    on='order_id',
    how='left'
)

# List of fields you want
fields = [
    'order_id', 'priority_score', 'pickup_dt', 'end_dt',
    'is_wedding', 'is_vip', 'pax_count', 'region'
]

# Print assignments grouped by driver
for driver_id, group in df_assigned_details.groupby('driver_id'):
    print(f"\nDriver {driver_id} assigned orders:")
    print(group[fields].sort_values('pickup_dt').to_string(index=False))
# Out:
# Driver DRV-001 assigned orders:
# order_id  priority_score           pickup_dt              end_dt  is_wedding  is_vip  pax_count region
#    Q3372            32.0 2024-11-02 19:00:00 2024-11-02 23:00:00       False   False         25  north
#
# Driver DRV-002 assigned orders:
# order_id  priority_score           pickup_dt              end_dt  is_wedding  is_vip  pax_count region
#    Q1662            67.0 2024-11-02 20:15:00 2024-11-03 00:15:00       False   False         60   west
#
# Driver DRV-008 assigned orders:
# order_id  priority_score           pickup_dt              end_dt  is_wedding  is_vip  pax_count region
#    N8029          1207.0 2024-11-02 18:30:00 2024-11-02 22:30:00        True    True        200   east
#    P2994           127.0 2024-11-03 02:00:00 2024-11-03 06:00:00        True   False        120   east
#
# Driver DRV-011 assigned orders:
# order_id  priority_score           pickup_dt              end_dt  is_wedding  is_vip  pax_count region
#    P9766            47.0 2024-11-03 01:45:00 2024-11-03 05:45:00       False   False         40   east
#
# Driver DRV-012 assigned orders:
# order_id  priority_score           pickup_dt              end_dt  is_wedding  is_vip  pax_count  region
#    O4397            61.0 2024-11-02 14:30:00 2024-11-03 00:30:00       False   False         60 central
#
# Driver DRV-013 assigned orders:
# order_id  priority_score           pickup_dt     end_dt  is_wedding  is_vip  pax_count region
#    O9254          1157.0 2024-11-02 20:00:00 2024-11-03        True    True        150   west
#
# Driver DRV-014 assigned orders:
# order_id  priority_score           pickup_dt              end_dt  is_wedding  is_vip  pax_count region
#    P9764            67.0 2024-11-03 00:15:00 2024-11-03 04:15:00       False   False         60   east
#
# Driver DRV-015 assigned orders:
# order_id  priority_score           pickup_dt              end_dt  is_wedding  is_vip  pax_count region
#    O9177            65.0 2024-11-02 15:45:00 2024-11-02 21:45:00       False   False         60   east
#
# Driver DRV-017 assigned orders:
# order_id  priority_score           pickup_dt              end_dt  is_wedding  is_vip  pax_count region
#    Q3373            22.0 2024-11-02 19:15:00 2024-11-02 23:15:00       False   False         15   west
#
# Driver DRV-018 assigned orders:
# order_id  priority_score           pickup_dt              end_dt  is_wedding  is_vip  pax_count region
#    Q3370            17.0 2024-11-03 02:00:00 2024-11-03 06:00:00       False   False         10  north
#
# Driver DRV-020 assigned orders:
# order_id  priority_score           pickup_dt              end_dt  is_wedding  is_vip  pax_count  region
#    Q5402           107.0 2024-11-02 22:00:00 2024-11-03 02:00:00       False   False        100 central
#
# Driver DRV-022 assigned orders:
# order_id  priority_score           pickup_dt              end_dt  is_wedding  is_vip  pax_count region
#    P8887          1207.0 2024-11-02 20:15:00 2024-11-03 00:15:00        True    True        200  north
#
# Driver DRV-025 assigned orders:
# order_id  priority_score           pickup_dt              end_dt  is_wedding  is_vip  pax_count  region
#    O4398            31.0 2024-11-02 14:45:00 2024-11-03 00:45:00       False   False         30 central
#
# Driver DRV-026 assigned orders:
# order_id  priority_score           pickup_dt              end_dt  is_wedding  is_vip  pax_count region
#    Q2717          1207.0 2024-11-02 19:45:00 2024-11-02 23:45:00        True    True        200   east
#
# Driver DRV-027 assigned orders:
# order_id  priority_score           pickup_dt              end_dt  is_wedding  is_vip  pax_count region
#    Q3371            27.0 2024-11-02 19:30:00 2024-11-02 23:30:00       False   False         20  north
#
# Driver DRV-036 assigned orders:
# order_id  priority_score           pickup_dt              end_dt  is_wedding  is_vip  pax_count  region
#    P6569            65.0 2024-11-02 15:45:00 2024-11-02 21:45:00       False   False         60 central
#    P5729            87.0 2024-11-03 02:45:00 2024-11-03 06:45:00       False   False         80 central
#
# Driver DRV-038 assigned orders:
# order_id  priority_score           pickup_dt              end_dt  is_wedding  is_vip  pax_count region
#    N8980           107.0 2024-11-02 18:00:00 2024-11-02 22:00:00        True   False        100   west
#    P2927          1157.0 2024-11-03 01:15:00 2024-11-03 05:15:00        True    True        150   west
#
# Driver DRV-040 assigned orders:
# order_id  priority_score           pickup_dt              end_dt  is_wedding  is_vip  pax_count region
#    Q4284            17.0 2024-11-02 19:45:00 2024-11-02 23:45:00       False   False         10  north
#
# Driver DRV-041 assigned orders:
# order_id  priority_score           pickup_dt              end_dt  is_wedding  is_vip  pax_count region
#    P7015          1187.0 2024-11-02 20:45:00 2024-11-03 00:45:00        True    True        180   west
#    N5760            87.0 2024-11-03 00:30:00 2024-11-03 04:30:00       False   False         80   west
#
# Driver DRV-042 assigned orders:
# order_id  priority_score           pickup_dt              end_dt  is_wedding  is_vip  pax_count  region
#    O4346            61.0 2024-11-02 15:30:00 2024-11-03 01:30:00       False   False         60 central
#
# Driver DRV-043 assigned orders:
# order_id  priority_score           pickup_dt              end_dt  is_wedding  is_vip  pax_count  region
#    Q4627          1207.0 2024-11-02 19:00:00 2024-11-02 23:00:00        True    True        200 central
#
# Driver DRV-049 assigned orders:
# order_id  priority_score           pickup_dt              end_dt  is_wedding  is_vip  pax_count region
#    Q4282            22.0 2024-11-02 19:45:00 2024-11-02 23:45:00       False   False         15  north
#    Q4280            22.0 2024-11-03 02:45:00 2024-11-03 06:45:00       False   False         15  north
#
# Driver DRV-050 assigned orders:
# order_id  priority_score           pickup_dt              end_dt  is_wedding  is_vip  pax_count region
#    P4047            17.0 2024-11-03 01:30:00 2024-11-03 05:30:00       False   False         10   west
#
# Driver DRV-052 assigned orders:
# order_id  priority_score           pickup_dt              end_dt  is_wedding  is_vip  pax_count region
#    P6984          1207.0 2024-11-02 18:45:00 2024-11-02 22:45:00        True    True        200   east
#    P9767            87.0 2024-11-03 02:45:00 2024-11-03 06:45:00       False   False         80   east
#
# Driver DRV-055 assigned orders:
# order_id  priority_score           pickup_dt              end_dt  is_wedding  is_vip  pax_count  region
#    O9950          1157.0 2024-11-02 18:30:00 2024-11-02 22:30:00        True    True        150 central
#    P6567            35.0 2024-11-02 21:30:00 2024-11-03 03:30:00       False   False         30 central
#
# Driver DRV-064 assigned orders:
# order_id  priority_score           pickup_dt              end_dt  is_wedding  is_vip  pax_count region
#    Q3819          1207.0 2024-11-02 20:45:00 2024-11-03 00:45:00        True    True        200   east
#    P9765            67.0 2024-11-03 00:00:00 2024-11-03 04:00:00       False   False         60   east
#
# Driver DRV-065 assigned orders:
# order_id  priority_score           pickup_dt              end_dt  is_wedding  is_vip  pax_count region
#    O9178           105.0 2024-11-02 16:00:00 2024-11-02 22:00:00       False   False        100   east
#    Q3374            37.0 2024-11-03 02:15:00 2024-11-03 06:15:00       False   False         30   east

# %%
all_driver_ids = {d['driver_id'] for d in drivers_capable}
allocated_driver_ids = set(df_assigned['driver_id'])
unallocated_driver_ids = all_driver_ids - allocated_driver_ids

print("Drivers with no assigned orders:")
for driver_id in unallocated_driver_ids:
    print(driver_id)
# Out:
# Drivers with no assigned orders:
# DRV-028
# DRV-010
# DRV-045
# DRV-063
# DRV-021
# DRV-054
# DRV-004
# DRV-034
# DRV-070
# DRV-059
# DRV-044
# DRV-024
# DRV-019
# DRV-003
# DRV-053
# DRV-047
# DRV-048
# DRV-057
# DRV-067
# DRV-009
# DRV-023
# DRV-035
# DRV-016
# DRV-062
# DRV-006
# DRV-032
# DRV-005
# DRV-058
# DRV-066
# DRV-030
# DRV-060
# DRV-007
# DRV-037
# DRV-061
# DRV-051
# DRV-046
# DRV-068
# DRV-069
# DRV-029
# DRV-031
# DRV-039
# DRV-056
# DRV-033

# %%
assigned_ids = set(order_id for order_id, driver_id in assigned)
unassigned_orders = df_orders[~df_orders['order_id'].isin(assigned_ids)]

columns = [
    'order_id', 'priority_score', 'pickup_dt', 'end_dt',
    'is_wedding', 'is_vip', 'pax_count', 'region'
]
display(unassigned_orders[columns])
# Out:
#    order_id  priority_score           pickup_dt              end_dt  \
# 14    Q3247          1207.0 2024-11-02 20:30:00 2024-11-03 00:30:00
# 9     Q3958          1207.0 2024-11-02 18:45:00 2024-11-02 22:45:00
# 26    P7916          1187.0 2024-11-02 20:15:00 2024-11-03 00:15:00
# 30    P4347          1187.0 2024-11-02 19:30:00 2024-11-02 23:30:00
# 10    N8347          1157.0 2024-11-02 19:00:00 2024-11-02 23:00:00
# 38    K9492          1157.0 2024-11-02 18:00:00 2024-11-02 22:00:00
# 11    Q1619          1157.0 2024-11-02 19:45:00 2024-11-02 23:45:00
# 18    P4436          1157.0 2024-11-02 19:15:00 2024-11-02 23:15:00
# 50    Q5082          1157.0 2024-11-02 19:00:00 2024-11-02 23:00:00
# 13    Q0753           127.0 2024-11-02 19:45:00 2024-11-02 23:45:00
# 23    P5232           127.0 2024-11-02 19:15:00 2024-11-02 23:15:00
# 12    Q3548           127.0 2024-11-02 18:45:00 2024-11-02 22:45:00
# 57    O3425           127.0 2024-11-02 19:15:00 2024-11-02 23:15:00
# 47    P6985           107.0 2024-11-02 20:45:00 2024-11-03 00:45:00
# 49    Q1717           107.0 2024-11-02 19:00:00 2024-11-02 23:00:00
# 34    P9688           107.0 2024-11-02 19:00:00 2024-11-02 23:00:00
# 59    P9890           107.0 2024-11-02 19:15:00 2024-11-02 23:15:00
# 17    Q4974           107.0 2024-11-02 18:15:00 2024-11-02 22:15:00
# 22    Q1194           107.0 2024-11-02 19:30:00 2024-11-02 23:30:00
# 19    O1841           107.0 2024-11-02 19:15:00 2024-11-02 23:15:00
# 35    Q3490            87.0 2024-11-02 18:45:00 2024-11-02 22:45:00
# 58    P4506            87.0 2024-11-02 20:45:00 2024-11-03 00:45:00
# 27    P8848            87.0 2024-11-02 19:45:00 2024-11-02 23:45:00
# 48    N4492            87.0 2024-11-02 20:30:00 2024-11-03 00:30:00
#
#     is_wedding  is_vip  pax_count   region
# 14        True    True        200    north
# 9         True    True        200    north
# 26        True    True        180     east
# 30        True    True        180    north
# 10        True    True        150  central
# 38        True    True        150  central
# 11        True    True        150    north
# 18        True    True        150     east
# 50        True    True        150    north
# 13        True   False        120     east
# 23        True   False        120    north
# 12        True   False        120     east
# 57        True   False        120    north
# 47        True   False        100     east
# 49        True   False        100    north
# 34        True   False        100     west
# 59        True   False        100    north
# 17        True   False        100     east
# 22        True   False        100  central
# 19        True   False        100    north
# 35        True   False         80    north
# 58        True   False         80     east
# 27        True   False         80     west
# 48        True   False         80    north

# %%
for idx, row in unassigned_orders.iterrows():
    possible_drivers = []
    for d, driver in enumerate(drivers_capable):
        # Region match
        if driver['preferred_region'] != row['region']:
            continue
        # Wedding capability
        if row['is_wedding'] and ('capabilities' not in driver or 'wedding' not in driver['capabilities']):
            continue
        # Max orders per day (you may want to count by date)
        # Overlap: in ILP, this is handled by constraints
        possible_drivers.append(driver['driver_id'])
    print(f"Order {row['order_id']} possible drivers: {possible_drivers}")
# Out:
# Order Q3247 possible drivers: ['DRV-022']
# Order Q3958 possible drivers: ['DRV-022']
# Order P7916 possible drivers: ['DRV-008', 'DRV-026', 'DRV-052', 'DRV-064']
# Order P4347 possible drivers: ['DRV-022']
# Order N8347 possible drivers: ['DRV-043', 'DRV-055']
# Order K9492 possible drivers: ['DRV-043', 'DRV-055']
# Order Q1619 possible drivers: ['DRV-022']
# Order P4436 possible drivers: ['DRV-008', 'DRV-026', 'DRV-052', 'DRV-064']
# Order Q5082 possible drivers: ['DRV-022']
# Order Q0753 possible drivers: ['DRV-008', 'DRV-026', 'DRV-052', 'DRV-064']
# Order P5232 possible drivers: ['DRV-022']
# Order Q3548 possible drivers: ['DRV-008', 'DRV-026', 'DRV-052', 'DRV-064']
# Order O3425 possible drivers: ['DRV-022']
# Order P6985 possible drivers: ['DRV-008', 'DRV-026', 'DRV-052', 'DRV-064']
# Order Q1717 possible drivers: ['DRV-022']
# Order P9688 possible drivers: ['DRV-013', 'DRV-038', 'DRV-041']
# Order P9890 possible drivers: ['DRV-022']
# Order Q4974 possible drivers: ['DRV-008', 'DRV-026', 'DRV-052', 'DRV-064']
# Order Q1194 possible drivers: ['DRV-043', 'DRV-055']
# Order O1841 possible drivers: ['DRV-022']
# Order Q3490 possible drivers: ['DRV-022']
# Order P4506 possible drivers: ['DRV-008', 'DRV-026', 'DRV-052', 'DRV-064']
# Order P8848 possible drivers: ['DRV-013', 'DRV-038', 'DRV-041']
# Order N4492 possible drivers: ['DRV-022']

# %% [markdown]
# ### PuLP with fairness penalty

# %%
import pulp
import pandas as pd
from itertools import product

# ... assume df_orders and drivers_capable are already defined ...

# Step 1: Build a list of possible driver-order assignments
assignments = []
order_idx = df_orders.index
for i in order_idx:
    o = df_orders.loc[i]
    for d, driver in enumerate(drivers_capable):
        if driver['preferred_region'] == o['region'] and 'wedding' in driver['capabilities']:
            assignments.append((i, d))

# Step 2: Define the problem
prob = pulp.LpProblem("OrderAssignment", pulp.LpMaximize)

# Decision variables: x[i, d] = 1 if order i is assigned to driver d
x = pulp.LpVariable.dicts("assign", assignments, 0, 1, pulp.LpBinary)

# Fairness penalty parameter (tune this value as needed)
FAIRNESS_PENALTY = 0.01

# --- Add job count variables for fairness penalty ---
job_count_vars = {}
for d in range(len(drivers_capable)):
    job_count_vars[d] = pulp.LpVariable(f"job_count_{d}", lowBound=0, cat='Integer')
    # job_count_vars[d] = sum of assignments to driver d
    prob += job_count_vars[d] == pulp.lpSum([x[(i, d)] for (i, dd) in assignments if dd == d])

# Objective: Maximize total priority score, penalize unbalanced driver loads (sum of squares)
prob += (
    pulp.lpSum([
        x[(i, d)] * df_orders.loc[i]['priority_score']
        for (i, d) in assignments
    ])
    - FAIRNESS_PENALTY * pulp.lpSum([job_count_vars[d] ** 2 for d in range(len(drivers_capable))])
)

# Constraint: Each order assigned at most once
for i in order_idx:
    prob += pulp.lpSum([x[(i, d)] for d in range(len(drivers_capable)) if (i, d) in x]) <= 1

# Constraint: Each driver can do at most max_orders_per_day per day
for d, driver in enumerate(drivers_capable):
    dates = set(df_orders['pickup_dt'])
    for date in dates:
        orders_on_date = df_orders[df_orders['pickup_dt'] == date].index
        prob += pulp.lpSum([x[(i, d)] for i in orders_on_date if (i, d) in x]) <= driver['max_orders_per_day']

# Constraint: No driver can take overlapping orders (precompute conflict pairs)
def overlap(o1, o2):
    return not (o1['end_dt'] <= o2['start_dt'] or o1['start_dt'] >= o2['end_dt'])

for d, driver in enumerate(drivers_capable):
    for date in set(df_orders['pickup_dt']):
        orders_on_date = df_orders[df_orders['pickup_dt'] == date]
        for i1, i2 in product(orders_on_date.index, repeat=2):
            if i1 < i2:
                o1, o2 = df_orders.loc[i1], df_orders.loc[i2]
                if overlap(o1, o2):
                    # Both not assigned to the same driver
                    if (i1, d) in x and (i2, d) in x:
                        prob += x[(i1, d)] + x[(i2, d)] <= 1

# Solve!
prob.solve()

# Extract assignment results
assigned = []
for (i, d), var in x.items():
    if var.varValue > 0.5:
        assigned.append((df_orders.loc[i]['order_id'], drivers_capable[d]['driver_id']))

print(f"Assigned {len(assigned)} orders out of {len(df_orders)} (ILP)")

# Show unassigned orders
assigned_ids = set(a[0] for a in assigned)
unassigned_orders = df_orders[~df_orders['order_id'].isin(assigned_ids)]
print(unassigned_orders[['order_id', 'priority_score', 'is_vip', 'pax_count', 'region']])

# Show number of orders per driver
import pandas as pd
df_assigned = pd.DataFrame(assigned, columns=['order_id', 'driver_id'])
order_counts = df_assigned['driver_id'].value_counts()
print("\nNumber of orders assigned per driver:")
print(order_counts)
